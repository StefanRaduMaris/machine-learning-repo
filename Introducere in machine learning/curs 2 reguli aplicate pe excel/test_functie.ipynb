# %%
import pandas as pd

df = pd.read_csv("clean_data.csv")

lista_pozitiv=["great", "excellent", "amazing", "love", "perfect", "good", "fantastic", "happy", "recommend"]
lista_negativa=["bad", "terrible", "worst", "broken", "poor", "disappointed", "awful", "hate", "slow"]
fraze_negative=['didn’t meet expectations', 'waste of money', 'heating issue']

# %%
if df['review'].str.contains(t in df['review'] for t in fraze_negative):
    df['clasificare']="negativ"
else:
    df['clasificare']='pozitiv'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 if df['review'].str.contains(t in df['review'] for t in fraze_negative):
#       2     df['clasificare']="negativ"
#       3 else:
#
# File c:\Users\Fane\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\strings\accessor.py:140, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     135     msg = (
#     136         f"Cannot use .str.{func_name} with values of "
#     137         f"inferred dtype '{self._inferred_dtype}'."
#     138     )
#     139     raise TypeError(msg)
# --> 140 return func(self, *args, **kwargs)
#
# File c:\Users\Fane\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\strings\accessor.py:1338, in StringMethods.contains(self, pat, case, flags, na, regex)
# ...
